# %% [markdown]
# <a href="https://colab.research.google.com/github/pourzand/Facial-Landmark-Detection-with-Deeplabv3-DSNT/blob/main/ashwhall%20Demo%20using%20DeepLabV3%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import tensorflow as tf
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# DeepLab Imports
from keras.layers import Activation,Conv2D,MaxPooling2D,BatchNormalization,Input,DepthwiseConv2D,add,Dropout,AveragePooling2D,Concatenate, Layer,InputSpec
from keras.models import Model														  
import keras.backend as K
# from keras.engine import Layer,InputSpec # This is from old keras/tf, 
from keras.utils import conv_utils

# %% [markdown]
# # Differentiable Spatial to Numerical Transform
# An example of the usage of the DSNT layer, as taken from the paper "Numerical Coordinate Regression with Convolutional Neural Networks"

# %%
# DSNT Function(s)

'''
A Tensorflow implementation of the DSNT layer, as taken from the paper "Numerical Coordinate
Regression with Convolutional Neural Networks"
'''

def dsnt(inputs, method='softmax', output_range='0to1'):
    '''
    Differentiable Spatial to Numerical Transform, as taken from the paper "Numerical Coordinate
    Regression with Convolutional Neural Networks"
    Arguments: 
        inputs - The learnt heatmap. A 4d tensor of shape [batch, height, width, channels]
        method - A string representing the normalisation method. See `_normalise_heatmap` for available methods
        output_range - output range for x,y. please choose "0to1" (inclusive range) or "-1to1" (exclusive range)
            The paper chooses "-1to1" range which includes only numbers between -1 to 1, but exclude -1 and 1.
    Returns:
        norm_heatmap - The given heatmap with normalisation/rectification applied
        coords_zipped - A tensor of shape [batch, channels, 2] containing the [x, y] coordinate pairs for each heatmap
    Example:
        Usage as a Keras layer (ignoring heatmap): `keras.layers.Lambda(lambda x: dsnt.dsnt(x, 'softmax')[1])`
        Should directly follow a Conv2D layer with linear activation.
    '''
    # Rectify and reshape inputs
    norm_heatmap = _normalise_heatmap(inputs, method)
    
    batch_count = tf.shape(norm_heatmap)[0]
    height = tf.shape(norm_heatmap)[1]
    width = tf.shape(norm_heatmap)[2]
    channels = norm_heatmap.shape[3]

    if output_range == '0to1':
        gen_range = lambda length: tf.range(length) / (length-1)
    elif output_range == '-1to1':
        gen_range = lambda length: (2 * tf.range(1, length+1) - (length+1)) / length
    else:
        raise ValueError("Unknown output_range: " + str(output_range))

    # Build the DSNT x, y matrices
    dsnt_x = tf.reshape(gen_range(width), [1, 1, -1, 1])
    dsnt_x = tf.tile(dsnt_x, [batch_count, height, 1, channels])
    dsnt_x = tf.cast(dsnt_x, tf.float32)
    dsnt_y = tf.reshape(gen_range(height), [1, -1, 1, 1])
    dsnt_y = tf.tile(dsnt_y, [batch_count, 1, width, channels])
    dsnt_y = tf.cast(dsnt_y, tf.float32)

    # Compute the Frobenius inner product
    outputs_x = tf.reduce_sum(tf.multiply(norm_heatmap, dsnt_x), axis=[1, 2])
    outputs_y = tf.reduce_sum(tf.multiply(norm_heatmap, dsnt_y), axis=[1, 2])

    # Zip into [x, y] pairs
    coords_zipped = tf.stack([outputs_x, outputs_y], axis=-1)

    return norm_heatmap, coords_zipped

def js_reg_loss(heatmaps, centres, fwhm=1):
    '''
    Calculates and returns the average Jensen-Shannon divergence between heatmaps and target Gaussians.
    Arguments:
        heatmaps - Heatmaps generated by the model
        centres - Centres of the target Gaussians (in normalized units)
        fwhm - Full-width-half-maximum for the drawn Gaussians, which can be thought of as a radius.
    '''
    gauss = _make_gaussians(centres, tf.shape(heatmaps)[1], tf.shape(heatmaps)[2], fwhm)
    divergences = _js_2d(heatmaps, gauss)
    return tf.reduce_mean(divergences)


def _normalise_heatmap(inputs, method='softmax'):
    '''
    Applies the chosen normalisation/rectification method to the input tensor
    Arguments:
        inputs - A 4d tensor of shape [batch, height, width, channels] (the learnt heatmap)
        method - A string representing the normalisation method. One of those shown below
    '''
    # Remove the final dimension as it's of size 1
#     inputs = tf.reshape(inputs, tf.shape(inputs)[:3])

    # Normalise the values such that the values sum to one for each heatmap
    normalise = lambda x: tf.divide(x, tf.reduce_sum(x, axis=[1, 2], keepdims=True))

    # Perform rectification
    if method == 'softmax':
        inputs = _softmax2d(inputs, axes=[1, 2])
    elif method == 'abs':
        inputs = tf.abs(inputs)
        inputs = normalise(inputs)
    elif method == 'relu':
        inputs = tf.nn.relu(inputs)
        inputs = normalise(inputs)
    elif method == 'sigmoid':
        inputs = tf.nn.sigmoid(inputs)
        inputs = normalise(inputs)
    else:
        msg = "Unknown rectification method \"{}\"".format(method)
        raise ValueError(msg)
    return inputs

def _kl_2d(p, q, eps=24):
    unsummed_kl = p * (tf.log(p + eps) - tf.log(q + eps))
    kl_values = tf.reduce_sum(unsummed_kl, [-1, -2])
    return kl_values

def _js_2d(p, q, eps=1e-24):
    m = 0.5 * (p + q)
    return 0.5 * _kl_2d(p, m, eps) + 0.5 * _kl_2d(q, m, eps)

def _softmax2d(target, axes):
    '''
    A softmax implementation which can operate across more than one axis - as this isn't
    provided by Tensorflow
    Arguments:
        targets - The tensor on which to apply softmax
        axes - An integer or list of integers across which to apply softmax
    '''
    max_axis = tf.reduce_max(target, axes, keepdims=True)
    target_exp = tf.exp(target-max_axis)
    normalize = tf.reduce_sum(target_exp, axes, keepdims=True)
    softmax = target_exp / normalize
    return softmax

def _make_gaussian(size, centre, fwhm=1):
        '''
        Makes a rectangular gaussian kernel.
        Arguments:
            size - A 2d tensor representing [height, width]
            centre - Pair of (normalised [0, 1]) x, y coordinates 
            fwhm - Full-width-half-maximum, which can be thought of as a radius.
        '''
        # Scale the normalised coordinates to be relative to the size of the frame
        centre = [centre[0] * tf.cast(size[1], tf.float32), 
                  centre[1] * tf.cast(size[0], tf.float32)]
        # Find the largest side, as we build a square and crop to desired size
        square_size = tf.cast(tf.reduce_max(size), tf.float32)

        x = tf.range(0, square_size, 1, dtype=tf.float32)
        y = x[:,tf.newaxis]
        x0 = centre[0] - 0.5
        y0 = centre[1] - 0.5
        unnorm = tf.exp(-4*tf.log(2.) * ((x-x0)**2 + (y-y0)**2) / fwhm**2)[:size[0],:size[1]]
        norm = unnorm / tf.reduce_sum(unnorm)
        return norm

def _make_gaussians(centres_in, height, width, fwhm=1):
    '''
    Makes a batch of gaussians. Size of images designated by height, width; number of images
    designated by length of the 1st dimension of centres_in
    Arguments:
        centres_in - The normalised coordinate centres of the gaussians of shape [batch, x, y]
        height - The desired height of the produced gaussian image
        width - The desired width of the produced gaussian image
        fwhm - Full-width-half-maximum, which can be thought of as a radius.
    '''
    def cond(centres, heatmaps):
        return tf.greater(tf.shape(centres)[0], 0)
    
    def body(centres, heatmaps):
        curr = centres[0]
        centres = centres[1:]
        new_heatmap = _make_gaussian([height, width], curr, fwhm)
        new_heatmap = tf.reshape(new_heatmap, [-1])
        
        heatmaps = tf.concat([heatmaps, new_heatmap], 0)
        return [centres, heatmaps]
    
    # Produce 1 heatmap per coordinate pair, build a list of heatmaps
    _, heatmaps_out = tf.while_loop(cond,
                                    body,
                                    [centres_in, tf.constant([])],
                                    shape_invariants=[tf.TensorShape([None, 2]), tf.TensorShape([None])])
    heatmaps_out = tf.reshape(heatmaps_out, [-1, height, width])
    return heatmaps_out

# %% [markdown]
# ## Build some dummy data
# Circles of random colour, size and position on a black background

# %%
img_size = 160
image_count = 20000
train_percent = 0.75
train_image_count = int(train_percent * image_count)
test_image_count = image_count - train_image_count

images = []
targets = []
for _ in range(20000):
    img = np.zeros((img_size, img_size, 3))
    row, col = np.random.randint(0, img_size), np.random.randint(0, img_size)
    radius = np.random.randint(8, 15)
    b, g, r = np.random.randint(0, 255), np.random.randint(0, 255), np.random.randint(0, 255)
    cv2.circle(img, (row, col), radius, (b, g, r), -1)
    images.append(img)
    norm_row = row / img_size
    norm_col = col / img_size
    targets.append([norm_row, norm_col])

images = np.array(images)
targets = np.array(targets)
train_images = images[:train_image_count]
test_images = images[train_image_count:]
train_targets = targets[:train_image_count]
test_targets = targets[train_image_count:]

print('''
{} images total
training: {}
testing : {}'''.format(image_count, train_image_count, test_image_count))

plt.imshow(train_images[0].astype('uint8'))
# Out:
# 200 images total
# training: 150
# testing : 50

# %%
print(train_targets.shape)
print(train_targets[0])
num_classes =1 # aka the number of landmarks per image, in this case just 1 landmark since the landmark is 1 dot
train_targets = train_targets.reshape(train_targets.shape[0],num_classes,2)
# data should now be compatible with the deeplabv3 model
# Out:
# (150, 2)
# [0.35625 0.8375 ]

# %%
print(train_targets.shape)
print(train_targets[0][0])
# Out:
# (150, 1, 2)
# [0.35625 0.8375 ]

# %% [markdown]
# ## The DeepLabV3+ Model
# Fully Connected Network with the final layer being the DSNT layer through the use of a keras lambda layer

# %%
class BilinearUpsampling(Layer):

    def __init__(self, upsampling=(2, 2), data_format=None, **kwargs):

        super(BilinearUpsampling, self).__init__(**kwargs)
        self.data_format = conv_utils.normalize_data_format(data_format)
        self.upsampling = conv_utils.normalize_tuple(upsampling, 2, 'size')
        self.input_spec = InputSpec(ndim=4)

    def compute_output_shape(self, input_shape):
        height = self.upsampling[0] * \
            input_shape[1] if input_shape[1] is not None else None
        width = self.upsampling[1] * \
            input_shape[2] if input_shape[2] is not None else None
        return (input_shape[0],
                height,
                width,
                input_shape[3])

    def call(self, inputs): # replaced K.tf.image.resize_bilenear with compat.v1.image.resize_bilinearr
        return K.tf.compat.v1.image.resize_bilinear(inputs, (int(inputs.shape[1]*self.upsampling[0]),
                                                   int(inputs.shape[2]*self.upsampling[1])))

    def get_config(self):
        config = {'size': self.upsampling,
                  'data_format': self.data_format}
        base_config = super(BilinearUpsampling, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
def xception_downsample_block(x,channels,top_relu=False):
	##separable conv1
	if top_relu:
		x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(channels,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	
	##separable conv2
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(channels,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	
	##separable conv3
	x=DepthwiseConv2D((3,3),strides=(2,2),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(channels,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	return x
def res_xception_downsample_block(x,channels):
	res=Conv2D(channels,(1,1),strides=(2,2),padding="same",use_bias=False)(x)
	res=BatchNormalization()(res)
	x=xception_downsample_block(x,channels)
	x=add([x,res])
	return x
def xception_block(x,channels):
	##separable conv1
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(channels,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	
	##separable conv2
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(channels,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	
	##separable conv3
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(channels,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	return x	
def res_xception_block(x,channels):
	res=x
	x=xception_block(x,channels)
	x=add([x,res])
	return x
def aspp(x,input_shape,out_stride):
	b0=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	b0=BatchNormalization()(b0)
	b0=Activation("relu")(b0)
	
	b1=DepthwiseConv2D((3,3),dilation_rate=(6,6),padding="same",use_bias=False)(x)
	b1=BatchNormalization()(b1)
	b1=Activation("relu")(b1)
	b1=Conv2D(256,(1,1),padding="same",use_bias=False)(b1)
	b1=BatchNormalization()(b1)
	b1=Activation("relu")(b1)
	
	b2=DepthwiseConv2D((3,3),dilation_rate=(12,12),padding="same",use_bias=False)(x)
	b2=BatchNormalization()(b2)
	b2=Activation("relu")(b2)
	b2=Conv2D(256,(1,1),padding="same",use_bias=False)(b2)
	b2=BatchNormalization()(b2)
	b2=Activation("relu")(b2)	

	b3=DepthwiseConv2D((3,3),dilation_rate=(12,12),padding="same",use_bias=False)(x)
	b3=BatchNormalization()(b3)
	b3=Activation("relu")(b3)
	b3=Conv2D(256,(1,1),padding="same",use_bias=False)(b3)
	b3=BatchNormalization()(b3)
	b3=Activation("relu")(b3)
	
	out_shape=int(input_shape[0]/out_stride)
	print("\noutput_shape: {} \n".format(out_shape))
	b4=AveragePooling2D(pool_size=(out_shape,out_shape))(x)

	b4=Conv2D(256,(1,1),padding="same",use_bias=False)(b4)
	b4=BatchNormalization()(b4)
	b4=Activation("relu")(b4)
	b4=BilinearUpsampling((out_shape,out_shape))(b4)
	
	x=Concatenate()([b4,b0,b1,b2,b3])
	return x
def deeplabv3_plus(input_shape=(96,96,1),out_stride=16,num_classes=15):
	
	img_input=Input(shape=input_shape) # OG
	print("input shape is the following: {} {} {}".format(input_shape[0], input_shape[1],input_shape[2]))
	#print(input_shape[0], input_shape[1],input_shape[2]) # not OG
	# img_input = tf.compat.v1.placeholder(tf.float32, shape=[None, input_shape[0], input_shape[1],input_shape[2]]) # Not OG

	
	x=Conv2D(32,(3,3),strides=(2,2),padding="same",use_bias=False)(img_input)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=Conv2D(64,(3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	
	x=res_xception_downsample_block(x,128)

	res=Conv2D(256,(1,1),strides=(2,2),padding="same",use_bias=False)(x)
	res=BatchNormalization()(res)	
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	skip=BatchNormalization()(x)
	x=Activation("relu")(skip)
	x=DepthwiseConv2D((3,3),strides=(2,2),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)	
	x=add([x,res])
	
	x=xception_downsample_block(x,728,top_relu=True)
	
	for i in range(16):
		x=res_xception_block(x,728)

	res=Conv2D(1024,(1,1),padding="same",use_bias=False)(x)
	res=BatchNormalization()(res)	
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(728,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(1024,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(1024,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)	
	x=add([x,res])
	
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(1536,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(1536,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Conv2D(2048,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)	
	x=Activation("relu")(x)
	
	#aspp
	x=aspp(x,input_shape,out_stride)
	x=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=Dropout(0.9)(x)
	
	##decoder 
	x=BilinearUpsampling((4,4))(x)
	dec_skip=Conv2D(48,(1,1),padding="same",use_bias=False)(skip)
	dec_skip=BatchNormalization()(dec_skip)
	dec_skip=Activation("relu")(dec_skip)
	x=Concatenate()([x,dec_skip])
	
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	
	x=DepthwiseConv2D((3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=Conv2D(256,(1,1),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	
	x=Conv2D(num_classes,(1,1),padding="same")(x)
	x=BilinearUpsampling((4,4))(x)
	x = Activation("sigmoid",name='last')(x)
	
	print("----------------")
	print("final shape of deeplab model {}".format(x.shape))
	print("----------------")
	
# 	norm_heatmap, coords = dsnt(x)
	
# 	print("\nshape of normalized heatmap {}".format(norm_heatmap.shape))
# 	print("\nshape of coordinates {}".format (coords.shape))

	# x = tf.keras.layers.Cropping2D(cropping=((5, 5), (5, 5)),name="crop")(x)

    		
	x = tf.keras.layers.Lambda(lambda x: dsnt(x, 'softmax')[1])(x)
	model=Model(img_input,x)
	
	# print(type(model))
	# return model
	
	# i guess you cant make a keras model with the placeholders
	# model=Model(img_input2,norm_heatmap)
	
	return model

# %%
def fcnModel(input_shape=(160,160,3),out_stride=16,num_classes=1):
	
	img_input=Input(shape=input_shape) # OG
	print("input shape is the following: {} {} {}".format(input_shape[0], input_shape[1],input_shape[2]))
	#print(input_shape[0], input_shape[1],input_shape[2]) # not OG
	# img_input = tf.compat.v1.placeholder(tf.float32, shape=[None, input_shape[0], input_shape[1],input_shape[2]]) # Not OG

	x=Conv2D(32,(3,3),strides=(2,2),padding="same",use_bias=False)(img_input)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
	x=Conv2D(64,(3,3),padding="same",use_bias=False)(x)
	x=BatchNormalization()(x)
	x=Activation("relu")(x)
    
    
	x = tf.nn.max_pool(x, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
# 	inputs = tf.keras.layers.Conv2D(filters=166,
#                         kernel_size=3,
#                         dilation_rate=1,
#                         padding='SAME',
#                         name='conv1')(img_input)
# 	inputs = tf.nn.relu(inputs)
# 	inputs = tf.nn.max_pool(inputs, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
# 	inputs = tf.keras.layers.Conv2D(filters=32,
#                         kernel_size=3,
#                         dilation_rate=2,
#                         padding='SAME',
#                         name='conv2')(inputs)
# 	inputs = tf.nn.relu(inputs)
# 	inputs = tf.nn.max_pool(inputs, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
# 	inputs = tf.keras.layers.Conv2D(filters=64,
#                         kernel_size=3,
#                         dilation_rate=4,
#                         padding='SAME',
#                         name='conv3')(inputs)
# 	inputs = tf.nn.relu(inputs)
# 	inputs = tf.nn.max_pool(inputs, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
	inputs = tf.keras.layers.Conv2D(filters=128,
                        kernel_size=3,
                        dilation_rate=8,
                        padding='SAME',
                        name='conv4')(x) # used to be 'inputs'
	inputs = tf.nn.relu(inputs)
	inputs = tf.nn.max_pool(inputs, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
	inputs = tf.keras.layers.Conv2D(filters=256,
                        kernel_size=3,
                        dilation_rate=16,
                        padding='SAME',
                        name='conv5')(inputs)
	inputs = tf.nn.relu(inputs)
	inputs = tf.nn.max_pool(inputs, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
	inputs = tf.keras.layers.Conv2D(filters=256,
                        kernel_size=3,
                        padding='SAME',
                        name='conv6')(inputs)
	inputs = tf.nn.relu(inputs)
	inputs = tf.nn.max_pool(inputs, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
	inputs = tf.keras.layers.Conv2D(filters=1,
                        kernel_size=1,
                        padding='SAME',
                        name='last2')(inputs)
	temp = tf.nn.relu(inputs,name='last3')

	print("----------------")
	print("final shape of fcn model {}".format(inputs.shape))
	print("----------------")
	
#
	x = tf.keras.layers.Lambda(lambda x: dsnt(inputs, 'softmax')[1])(temp)
	model=Model(img_input,x)
	

	
	return model

# %% [markdown]
# ## Training
# A very simple training loop with no mini-batching.

# %%
tf.compat.v1.disable_eager_execution()

model = deeplabv3_plus(input_shape=(160,160,3),out_stride=16,num_classes=1) # segments into background and foreground i think
fcnBasic = fcnModel(input_shape=(160,160,3),out_stride=16,num_classes=1)
#fcnBasic.summary()
# Out:
# input shape is the following: 160 160 3
# WARNING:tensorflow:From /Users/seena/miniforge3/envs/seenaTest/lib/python3.9/site-packages/keras/layers/normalization/batch_normalization.py:514: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
#
# output_shape: 10
#
# ----------------
# final shape of deeplab model (None, 160, 160, 1)
# ----------------
# input shape is the following: 160 160 3
# ----------------
# final shape of fcn model (None, 5, 5, 1)
# ----------------

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=50)
# to Stop training if there is no improvements

model.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])


model.fit(train_images, train_targets, batch_size=64, epochs=1024, callbacks=[callback])
                            
inputs = model.input   
outputs= model.get_layer('last').output

pureDLV3 = Model(inputs,outputs)
# Out:
# Train on 150 samples
# Epoch 1/1024
# 150/150 [==============================] - 28s 185ms/sample - loss: 0.0745 - accuracy: 0.6867
# Epoch 2/1024
# 150/150 [==============================] - 18s 119ms/sample - loss: 0.0560 - accuracy: 0.9667
# Epoch 3/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0468 - accuracy: 0.9467
# Epoch 4/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0455 - accuracy: 0.9467
# Epoch 5/1024
# 150/150 [==============================] - 14s 97ms/sample - loss: 0.0442 - accuracy: 0.9400
# Epoch 6/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0435 - accuracy: 0.9733
# Epoch 7/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0431 - accuracy: 0.9533
# Epoch 8/1024
# 150/150 [==============================] - 75s 502ms/sample - loss: 0.0430 - accuracy: 0.9667
# Epoch 9/1024
# 150/150 [==============================] - 16s 110ms/sample - loss: 0.0429 - accuracy: 0.9733
# Epoch 10/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0429 - accuracy: 0.9867
# Epoch 11/1024
# 150/150 [==============================] - 401s 3s/sample - loss: 0.0428 - accuracy: 0.9733
# Epoch 12/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0427 - accuracy: 0.9867
# Epoch 13/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0427 - accuracy: 0.9933
# Epoch 14/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0427 - accuracy: 0.9800
# Epoch 15/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0427 - accuracy: 0.9733
# Epoch 16/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0426 - accuracy: 0.9800
# Epoch 17/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0426 - accuracy: 0.9933
# Epoch 18/1024
# 150/150 [==============================] - 16s 110ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 19/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 20/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0426 - accuracy: 0.9800
# Epoch 21/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0426 - accuracy: 1.0000
# Epoch 22/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0426 - accuracy: 0.9933
# Epoch 23/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 24/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0426 - accuracy: 0.9933
# Epoch 25/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0426 - accuracy: 0.9933
# Epoch 26/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 27/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 28/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 29/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0426 - accuracy: 1.0000
# Epoch 30/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0426 - accuracy: 1.0000
# Epoch 31/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0426 - accuracy: 0.9933
# Epoch 32/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 33/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0426 - accuracy: 0.9800
# Epoch 34/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0426 - accuracy: 0.9867
# Epoch 35/1024
# 150/150 [==============================] - 12s 78ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 36/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 37/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 0.9800
# Epoch 38/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 39/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 40/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 41/1024
# 150/150 [==============================] - 12s 79ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 42/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 43/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 44/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 45/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 46/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 47/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 48/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 49/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 50/1024
# 150/150 [==============================] - 11s 77ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 51/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 52/1024
# 150/150 [==============================] - 12s 79ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 53/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 54/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 55/1024
# 150/150 [==============================] - 9s 59ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 56/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 57/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 58/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 59/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 60/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 61/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 62/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 0.9800
# Epoch 63/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 64/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 65/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 66/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 67/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 68/1024
# 150/150 [==============================] - 136s 907ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 69/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 70/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 71/1024
# 150/150 [==============================] - 64s 427ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 72/1024
# 150/150 [==============================] - 23s 155ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 73/1024
# 150/150 [==============================] - 1317s 9s/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 74/1024
# 150/150 [==============================] - 18s 123ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 75/1024
# 150/150 [==============================] - 20s 130ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 76/1024
# 150/150 [==============================] - 17s 115ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 77/1024
# 150/150 [==============================] - 18s 117ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 78/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 79/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 80/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 81/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 82/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 83/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 84/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 85/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 86/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 87/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 88/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 89/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 0.9800
# Epoch 90/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 91/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 92/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 93/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 94/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 95/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 96/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 97/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 98/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 99/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 100/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 101/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 102/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 103/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 104/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 105/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 106/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 107/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 108/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 109/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 110/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 111/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 112/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 113/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 114/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 115/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 116/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 117/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 118/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 119/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 120/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 121/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 122/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 123/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 124/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 125/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 126/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 127/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 128/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 129/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 130/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 131/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 132/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 133/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 134/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 135/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 136/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 137/1024
# 150/150 [==============================] - 21s 138ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 138/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 139/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 140/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 141/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 142/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 143/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 144/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 145/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 146/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 147/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 148/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 149/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 150/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 151/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 152/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 153/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 154/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 155/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 156/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 157/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 158/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 159/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 160/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 161/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 162/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 163/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 164/1024
# 150/150 [==============================] - 19s 126ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 165/1024
# 150/150 [==============================] - 18s 121ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 166/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 167/1024
# 150/150 [==============================] - 18s 119ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 168/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 169/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 170/1024
# 150/150 [==============================] - 17s 115ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 171/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 172/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 173/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 174/1024
# 150/150 [==============================] - 17s 115ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 175/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 176/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 177/1024
# 150/150 [==============================] - 17s 113ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 178/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 179/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 180/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 181/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 182/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 183/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 184/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 185/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 186/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 187/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 188/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 189/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 190/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 191/1024
# 150/150 [==============================] - 17s 113ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 192/1024
# 150/150 [==============================] - 18s 117ms/sample - loss: 0.0425 - accuracy: 0.9800
# Epoch 193/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 194/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 195/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 196/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 197/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 198/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 199/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 200/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 201/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 202/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 203/1024
# 150/150 [==============================] - 18s 123ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 204/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 205/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 206/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 207/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 208/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 209/1024
# 150/150 [==============================] - 16s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 210/1024
# 150/150 [==============================] - 18s 120ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 211/1024
# 150/150 [==============================] - 17s 112ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 212/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 213/1024
# 150/150 [==============================] - 17s 110ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 214/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 215/1024
# 150/150 [==============================] - 14s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 216/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 217/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 218/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 219/1024
# 150/150 [==============================] - 16s 110ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 220/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 221/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 222/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 223/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 224/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 225/1024
# 150/150 [==============================] - 17s 115ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 226/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 227/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 228/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 229/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 230/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 231/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 232/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 233/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 234/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 235/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 236/1024
# 150/150 [==============================] - 16s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 237/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 238/1024
# 150/150 [==============================] - 16s 110ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 239/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 240/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 241/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 242/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 243/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 244/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 245/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 246/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 247/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 248/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 249/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 250/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 251/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 252/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 253/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 254/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 0.9867
# Epoch 255/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 256/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 257/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 258/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 259/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 260/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 261/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 262/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 263/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 264/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 265/1024
# 150/150 [==============================] - 12s 79ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 266/1024
# 150/150 [==============================] - 12s 78ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 267/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 268/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 269/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 270/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 271/1024
# 150/150 [==============================] - 13s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 272/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 273/1024
# 150/150 [==============================] - 13s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 274/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 275/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 276/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 277/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 278/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 279/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 280/1024
# 150/150 [==============================] - 12s 79ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 281/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 282/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 283/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 284/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 0.9800
# Epoch 285/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 286/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 287/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 288/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 289/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 290/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 291/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 292/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 293/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 294/1024
# 150/150 [==============================] - 12s 79ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 295/1024
# 150/150 [==============================] - 11s 77ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 296/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 297/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 298/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 299/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 300/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 301/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 302/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 303/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 304/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 305/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 306/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 307/1024
# 150/150 [==============================] - 12s 77ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 308/1024
# 150/150 [==============================] - 13s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 309/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 310/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 311/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 312/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 313/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 314/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 315/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 316/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 317/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 318/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 319/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 320/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 321/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 322/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 323/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 324/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 325/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 326/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 327/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 328/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 329/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 330/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 331/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 332/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 333/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 334/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 335/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 336/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 337/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 338/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 339/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 340/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 341/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 342/1024
# 150/150 [==============================] - 17s 114ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 343/1024
# 150/150 [==============================] - 20s 135ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 344/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 345/1024
# 150/150 [==============================] - 983s 7s/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 346/1024
# 150/150 [==============================] - 24s 160ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 347/1024
# 150/150 [==============================] - 22s 145ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 348/1024
# 150/150 [==============================] - 20s 136ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 349/1024
# 150/150 [==============================] - 20s 132ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 350/1024
# 150/150 [==============================] - 937s 6s/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 351/1024
# 150/150 [==============================] - 18s 119ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 352/1024
# 150/150 [==============================] - 18s 123ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 353/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 354/1024
# 150/150 [==============================] - 19s 125ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 355/1024
# 150/150 [==============================] - 20s 132ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 356/1024
# 150/150 [==============================] - 19s 126ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 357/1024
# 150/150 [==============================] - 23s 151ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 358/1024
# 150/150 [==============================] - 24s 157ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 359/1024
# 150/150 [==============================] - 26s 171ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 360/1024
# 150/150 [==============================] - 24s 162ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 361/1024
# 150/150 [==============================] - 25s 167ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 362/1024
# 150/150 [==============================] - 28s 189ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 363/1024
# 150/150 [==============================] - 36s 239ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 364/1024
# 150/150 [==============================] - 303s 2s/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 365/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 366/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 367/1024
# 150/150 [==============================] - 44s 294ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 368/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 369/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 370/1024
# 150/150 [==============================] - 499s 3s/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 371/1024
# 150/150 [==============================] - 21s 139ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 372/1024
# 150/150 [==============================] - 19s 128ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 373/1024
# 150/150 [==============================] - 17s 116ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 374/1024
# 150/150 [==============================] - 16s 109ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 375/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 376/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 377/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 378/1024
# 150/150 [==============================] - 16s 107ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 379/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 380/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 381/1024
# 150/150 [==============================] - 12s 79ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 382/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 383/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 384/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 385/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 386/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 387/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 388/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 389/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 390/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 391/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 392/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 393/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 394/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 395/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 396/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 397/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 398/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 399/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 400/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 401/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 402/1024
# 150/150 [==============================] - 12s 81ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 403/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 404/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 405/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 406/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 407/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 408/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 409/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 410/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 411/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 412/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 413/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 414/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 415/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 416/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 417/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 418/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 419/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 420/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 421/1024
# 150/150 [==============================] - 14s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 422/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 423/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 424/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 425/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 426/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 427/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 428/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 429/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 430/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 431/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 432/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 433/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 434/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 435/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 436/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 437/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 438/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 439/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 440/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 441/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 442/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 443/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 444/1024
# ...
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 821/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 822/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 823/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 824/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 825/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 826/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 827/1024
# 150/150 [==============================] - 12s 82ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 828/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 829/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 830/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 831/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 832/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 833/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 834/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 835/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 836/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 837/1024
# 150/150 [==============================] - 10s 69ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 838/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 839/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 840/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 841/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 842/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 843/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 844/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 845/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 846/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 847/1024
# 150/150 [==============================] - 18s 117ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 848/1024
# 150/150 [==============================] - 17s 115ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 849/1024
# 150/150 [==============================] - 16s 110ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 850/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 851/1024
# 150/150 [==============================] - 15s 97ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 852/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 853/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 854/1024
# 150/150 [==============================] - 15s 103ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 855/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 856/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 857/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 858/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 859/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 860/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 0.9933
# Epoch 861/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 862/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 863/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 864/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 865/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 866/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 867/1024
# 150/150 [==============================] - 12s 77ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 868/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 869/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 870/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 871/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 872/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 873/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 874/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 875/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 876/1024
# 150/150 [==============================] - 11s 76ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 877/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 878/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 879/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 880/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 881/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 882/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 883/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 884/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 885/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 886/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 887/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 888/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 889/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 890/1024
# 150/150 [==============================] - 17s 111ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 891/1024
# 150/150 [==============================] - 16s 108ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 892/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 893/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 894/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 895/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 896/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 897/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 898/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 899/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 900/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 901/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 902/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 903/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 904/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 905/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 906/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 907/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 908/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 909/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 910/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 911/1024
# 150/150 [==============================] - 15s 101ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 912/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 913/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 914/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 915/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 916/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 917/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 918/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 919/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 920/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 921/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 922/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 923/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 924/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 925/1024
# 150/150 [==============================] - 17s 113ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 926/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 927/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 928/1024
# 150/150 [==============================] - 18s 122ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 929/1024
# 150/150 [==============================] - 15s 100ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 930/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 931/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 932/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 933/1024
# 150/150 [==============================] - 15s 99ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 934/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 935/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 936/1024
# 150/150 [==============================] - 14s 96ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 937/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 938/1024
# 150/150 [==============================] - 13s 87ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 939/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 940/1024
# 150/150 [==============================] - 14s 92ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 941/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 942/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 943/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 944/1024
# 150/150 [==============================] - 14s 91ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 945/1024
# 150/150 [==============================] - 14s 93ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 946/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 947/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 948/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 949/1024
# 150/150 [==============================] - 13s 84ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 950/1024
# 150/150 [==============================] - 13s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 951/1024
# 150/150 [==============================] - 13s 86ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 952/1024
# 150/150 [==============================] - 12s 80ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 953/1024
# 150/150 [==============================] - 14s 94ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 954/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 955/1024
# 150/150 [==============================] - 16s 106ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 956/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 957/1024
# 150/150 [==============================] - 15s 98ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 958/1024
# 150/150 [==============================] - 16s 105ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 959/1024
# 150/150 [==============================] - 15s 102ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 960/1024
# 150/150 [==============================] - 14s 95ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 961/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 962/1024
# 150/150 [==============================] - 16s 104ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 963/1024
# 150/150 [==============================] - 12s 83ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 964/1024
# 150/150 [==============================] - 13s 89ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 965/1024
# 150/150 [==============================] - 13s 88ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 966/1024
# 150/150 [==============================] - 14s 90ms/sample - loss: 0.0425 - accuracy: 1.0000
# Epoch 967/1024
# 150/150 [==============================] - 13s 85ms/sample - loss: 0.0425 - accuracy: 1.0000

# %%
fcnBasic.compile(optimizer='adam',
              loss=tf.keras.losses.MeanSquaredError(),
              metrics=['accuracy'])


fcnBasic.fit(train_images, train_targets, batch_size=16, epochs=25)

# %%
test_targets = test_targets.reshape(test_targets.shape[0],num_classes,2)

results = model.evaluate(test_images, test_targets, batch_size=32)
print("test loss, test acc:", results)
# Out:
# /Users/seena/miniforge3/envs/seenaTest/lib/python3.9/site-packages/keras/engine/training_v1.py:2045: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# test loss, test acc: [0.04484085566638699, 0.98569274]

# %%
predicts = pureDLV3.predict(test_images) # Used to be test_images
print(predicts.shape)


# fcnIn = fcnBasic.input
# fcnOut = fcnBasic.get_layer('last2').output
# fcnHeat = Model(fcnIn,fcnOut) 
# earlyPredict = fcnHeat.predict(test_images)
# print(earlyPredict.shape)

actPredicts = model.predict(test_images) # Used to be test_images
# Out:
# (19850, 160, 160, 1)

# %%
newPredicts = np.einsum('ijkl->iljk',predicts )

for numImage in range(3,6):
    f, ax = plt.subplots(1, 3, figsize=(20,20))   
    ax[0].imshow((newPredicts[numImage][0]),cmap="gray")
    ax[0].scatter((160 * test_targets[numImage][0][0]),(160 * test_targets[numImage][0][1]),c = 'white') # Used to be test_targets
    ax[0].set_title( "DeepLabV3 PreDSNT Output", fontsize=20)

    ax[1].imshow(test_images[numImage].astype('uint8')) # Used to be test_images
    ax[1].scatter((160 * test_targets[numImage][0][0]),(160 * test_targets[numImage][0][1]),c = 'white')
    ax[1].set_title( "Test Data(Image & Coords))", fontsize=20)

    ax[2].imshow(test_images[numImage].astype('uint8')) # Used to be test_images
    ax[2].scatter((160 * actPredicts[numImage][0][0]),(160 * actPredicts[numImage][0][1]),c = 'red')
    ax[2].set_title( "DSNT + DeepLab Predicted Coords", fontsize=20)

# %% [markdown]
# # Above on the left is the output of a deeplab segmentation when fed in the dots and the coordinates of the dots. Dot is plotted as well for reference. Right is example of training data appearance and the corresponding coordinate as well as deeplabv3 predicted coordinate in red

# %% [markdown]
# ## It is a bit hard to tell but in some of the DeepLab segmentation pre DSNT plots, there is a very faint highlight around the points, so the deeplab is detecting the points but it is also detects the edges much more(shown with the bright white lines around the border of every image) which is what I suspect is causing it to continually plot points in the center

# %% [markdown]
# #### To take away these bright white lines which highlight the borders/edges of the image, which i suspect are warping the dsnt predictions, I crop the image slightly to remove the bright white edges, and then replace it with zero padding so the image remains the same size. Yes, this would affect any cases where the point might be near the edge, but this is purely for debugging purposes

# %%
for numImage in range(3,6):
    f, ax = plt.subplots(1, 4, figsize=(20,20))   
    tempArr = newPredicts[numImage][0][8:152, 8:152]
    tempArr = np.pad(tempArr, 8,constant_values = 0.0011) # the value of 0.0011 just makes it more visible to see the heatmap 
    tempArr *= 1

    # used to be (newPredicts[numImage][0])
    ax[0].imshow(tempArr,cmap="gray")
    ax[0].scatter((160 * test_targets[numImage][0][0]),(160 * test_targets[numImage][0][1]),c = 'black')
    ax[0].set_title( "DeepLabV3 PreDSNT \n Output w Actual Coords\n(Removed white edges)", fontsize=20)


    ax[1].imshow(test_images[numImage].astype('uint8'))
    ax[1].scatter((160 * test_targets[numImage][0][0]),(160 * test_targets[numImage][0][1]),c = 'white')
    ax[1].set_title( "Test Data \n(Image & Coords))", fontsize=20)


    ax[2].imshow(test_images[numImage].astype('uint8'))
    ax[2].scatter((160 * actPredicts[numImage][0][0]),(160 * actPredicts[numImage][0][1]),c = 'red')
    ax[2].set_title( "DSNT + DeepLab \nPredicted Coords", fontsize=20)
    
    tempArr[10:150, 10:150] *= 10 # Just so we can make sure the highlighted parts of output have the greatest value
    
    tempCoords = np.unravel_index(np.argmax(tempArr, axis=None), tempArr.shape,order='F')
    
    ax[3].imshow(test_images[numImage].astype('uint8'))
    ax[3].scatter((tempCoords[0]),(tempCoords[1]),c = 'black')
    ax[3].set_title( "Argmax DeepLab Segmented \n Predicted Coords", fontsize=20)
    
    print("Argmax Predict for Image {}".format(numImage+1))
    print(np.unravel_index(np.argmax(tempArr, axis=None), tempArr.shape,order='F'))
    print("Actual Coord for Image {}".format(numImage+1))
    print((160 * test_targets[numImage][0][0]),(160 * test_targets[numImage][0][1]))
    print("_____________________")
# Out:
# Argmax Predict for Image 4
# (72, 56)
# Actual Coord for Image 4
# 74.0 55.0
# _____________________
# Argmax Predict for Image 5
# (20, 124)
# Actual Coord for Image 5
# 20.0 118.0
# _____________________
# Argmax Predict for Image 6
# (120, 16)
# Actual Coord for Image 6
# 121.0 14.0
# _____________________

# %% [markdown]
# ## So from what I can tell the weird bright edges were affecting the DSNT calculation, causing it to always calculate the landmark aka point to be in the center of the image every single time

# %% [markdown]
# ## Now the brightest parts of the heatmap are where it thinks the actual circle is, not the bright lines so in theory it should predict better, however, when looking at the heatmaps for the facial landmark example, it does not have such issues so Im finding it harder to debug

# %%
print(earlyPredict.shape)
print(earlyPredict[0][0][0])

fcnPredicts = fcnBasic.predict(test_images)

# f, ax = plt.subplots(1, 2, figsize=(20,20))

# ax[0].imshow((earlyPredict[0]),cmap="gray")
# ax[0].scatter((5 * test_targets[0][0][0]),(5 * test_targets[0][0][1]),c = 'red')

# ax[1].imshow(test_images[0].astype('uint8'))
# ax[1].scatter((160 * test_targets[0][0][0]),(160 * test_targets[0][0][1]),c = 'white')


for numImage in range(6):
    f, ax = plt.subplots(1, 3, figsize=(20,20))

    ax[0].imshow((earlyPredict[numImage]),cmap="gray")
    ax[0].scatter((5 * test_targets[numImage][0][0]),(5 * test_targets[numImage][0][1]),c = 'red')
    ax[0].set_title( "FCN PreDSNT Output", fontsize=20)


    ax[1].imshow(test_images[numImage].astype('uint8'))
    ax[1].scatter((160 * test_targets[numImage][0][0]),(160 * test_targets[numImage][0][1]),c = 'white')
    ax[1].set_title( "Test Data(Image & Coords))", fontsize=20)


    ax[2].imshow(test_images[numImage].astype('uint8'))
    ax[2].scatter((160 * fcnPredicts[numImage][0][0]),(160 * fcnPredicts[numImage][0][1]),c = 'yellow')
    ax[2].set_title( "DSNT + FCN Predicted Coords", fontsize=20)
# Out:
# (50, 5, 5, 1)
# [-2.8192096]

# %% [markdown]
# # Above on the left is the output of a basic fcn segmentation when fed in the dots and the coordinates of the dots. Dot is plotted as well for reference. right is example of training data appearance and the corresponding coordinate as well as fcn predicted coordinate in yellow
